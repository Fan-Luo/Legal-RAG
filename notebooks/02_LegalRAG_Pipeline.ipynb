# %% [markdown]
# ---
# title: "[Run LegalRAG Pipeline](https://colab.research.google.com/drive/1TRp4d_VwlcSY8f78psuCNX_90WA3g6qS?usp=sharing)"
# ---

# %% [markdown]
# This notebook demonstrates the end-to-end behavior of the Legal RAG system, covering data preprocessing, query understanding, routing, hybrid retrieval, and evidence-backed response generation.

# %% [markdown]
# ## Repository Install
#
# First, pull the project source code and initialize the execution environment.
#
# ```python
# git clone https://github.com/Fan-Luo/Legal-RAG.git
# cd Legal-RAG
# pip install -e .
# ```

# %%
#| include: false

import logging

def setup_logging(
    level=logging.INFO,
    fmt="%(message)s",
    scope="legalrag",
):
    """
    Configure logging for the LegalRAG repository.

    This function removes existing handlers attached to loggers
    under the given scope and installs a clean StreamHandler.
    """
    base = logging.getLogger(scope)
    base.setLevel(level)

    # Remove all handlers under this scope
    for name, logger in logging.root.manager.loggerDict.items():
        if name == scope or name.startswith(scope + "."):
            lg = logging.getLogger(name)
            for h in lg.handlers[:]:
                lg.removeHandler(h)
            lg.propagate = False

    # Attach a single handler to base logger
    handler = logging.StreamHandler()
    handler.setFormatter(logging.Formatter(fmt))
    base.addHandler(handler)

setup_logging(fmt="%(message)s")

# %%
#| include: false

from pathlib import Path
import os, subprocess

ROOT = Path("/content").resolve()
REPO_URL = "https://github.com/Fan-Luo/Legal-RAG.git"
REPO_DIR = ROOT / "Legal-RAG"
os.environ["REPO_DIR"] = str(REPO_DIR)

def run(cmd, cwd=None):
    res = subprocess.run(cmd, cwd=cwd, text=True, stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
    if res.returncode != 0:
        tail="\n".join(res.stdout.splitlines()[-40:])
        raise RuntimeError(f"Command failed: {cmd}\n--- output tail ---\n{tail}")
    return res.stdout

# print(f"Working directory: {ROOT}")
if not REPO_DIR.exists():
    run(["git","clone","--depth","1",REPO_URL,str(REPO_DIR)])
    # print(f"Cloned repo to: {REPO_DIR}")
else:
    run(["git","pull"], cwd=str(REPO_DIR))
    # print(f"Updated repo at: {REPO_DIR}")

os.chdir(REPO_DIR)
print("Current dir:", Path.cwd())
# Out:
# Current dir: /content/Legal-RAG

# %%
#| include: false

from scripts.quiet import install_quiet
import subprocess, textwrap

install_quiet()
print("Quiet mode enabled: suppressed noisy logs/warnings; keeping meaningful tables/figures.")

print("Environment check:")
try:
    out = subprocess.run(["nvidia-smi"], text=True, stdout=subprocess.PIPE, stderr=subprocess.STDOUT).stdout
    # Keep only first ~15 lines to avoid noisy GPU inventory dumps
    print("\n".join(out.splitlines()[:15]))
except Exception:
    print("No GPU detected (this is fine). Using CPU.")
# Out:
# Quiet mode enabled: suppressed noisy logs/warnings; keeping meaningful tables/figures.
# Environment check:
# Mon Feb  2 03:14:44 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |

# %%
#| include: false

# %%bash
set -e
cd "$REPO_DIR" || exit 1

pip install --upgrade pip
pip install --upgrade -e .
echo "Dependencies installed."
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-26.0-py3-none-any.whl.metadata (4.7 kB)
# Downloading pip-26.0-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 36.9 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-26.0
# Obtaining file:///content/Legal-RAG
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Collecting colbert-ai>=0.2.19 (from legal-rag==0.1.0)
#   Downloading colbert_ai-0.2.22-py3-none-any.whl.metadata (12 kB)
# Collecting faiss-cpu>=1.7.4 (from legal-rag==0.1.0)
#   Downloading faiss_cpu-1.13.2-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (7.6 kB)
# Requirement already satisfied: fastapi>=0.110 in /usr/local/lib/python3.12/dist-packages (from legal-rag==0.1.0) (0.123.10)
# Collecting flagembedding>=1.2.10 (from legal-rag==0.1.0)
#   Downloading FlagEmbedding-1.3.5.tar.gz (163 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: httpx>=0.25 in /usr/local/lib/python3.12/dist-packages (from legal-rag==0.1.0) (0.28.1)
# Collecting jedi>=0.16 (from legal-rag==0.1.0)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: jieba>=0.42.1 in /usr/local/lib/python3.12/dist-packages (from legal-rag==0.1.0) (0.42.1)
# Collecting loguru>=0.7 (from legal-rag==0.1.0)
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: matplotlib>=3.8.0 in /usr/local/lib/python3.12/dist-packages (from legal-rag==0.1.0) (3.10.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from legal-rag==0.1.0) (3.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from legal-rag==0.1.0) (2.0.2)
# Requirement already satisfied: openai>=1.0 in /usr/local/lib/python3.12/dist-packages (from legal-rag==0.1.0) (2.16.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from legal-rag==0.1.0) (2.2.2)
# Collecting pdfplumber (from legal-rag==0.1.0)
#   Downloading pdfplumber-0.11.9-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: pydantic>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from legal-rag==0.1.0) (2.12.3)
# Collecting pyvis (from legal-rag==0.1.0)
#   Downloading pyvis-0.3.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: pyyaml>=6.0 in /usr/local/lib/python3.12/dist-packages (from legal-rag==0.1.0) (6.0.3)
# Collecting rank-bm25>=0.2.2 (from legal-rag==0.1.0)
#   Downloading rank_bm25-0.2.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.12/dist-packages (from legal-rag==0.1.0) (2.32.4)
# Requirement already satisfied: scipy>=1.10 in /usr/local/lib/python3.12/dist-packages (from legal-rag==0.1.0) (1.16.3)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.12/dist-packages (from legal-rag==0.1.0) (5.2.2)
# Requirement already satisfied: tqdm>=4.66 in /usr/local/lib/python3.12/dist-packages (from legal-rag==0.1.0) (4.67.1)
# Requirement already satisfied: uvicorn>=0.27 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.27->legal-rag==0.1.0) (0.40.0)
# Collecting bitarray (from colbert-ai>=0.2.19->legal-rag==0.1.0)
#   Downloading bitarray-3.8.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (34 kB)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (from colbert-ai>=0.2.19->legal-rag==0.1.0) (4.0.0)
# Requirement already satisfied: flask in /usr/local/lib/python3.12/dist-packages (from colbert-ai>=0.2.19->legal-rag==0.1.0) (3.1.2)
# Requirement already satisfied: GitPython in /usr/local/lib/python3.12/dist-packages (from colbert-ai>=0.2.19->legal-rag==0.1.0) (3.1.46)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from colbert-ai>=0.2.19->legal-rag==0.1.0) (1.2.1)
# Collecting ninja (from colbert-ai>=0.2.19->legal-rag==0.1.0)
#   Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from colbert-ai>=0.2.19->legal-rag==0.1.0) (4.57.6)
# Collecting ujson (from colbert-ai>=0.2.19->legal-rag==0.1.0)
#   Downloading ujson-5.11.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (9.4 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu>=1.7.4->legal-rag==0.1.0) (25.0)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.110->legal-rag==0.1.0) (0.50.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.110->legal-rag==0.1.0) (4.15.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.110->legal-rag==0.1.0) (0.0.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->legal-rag==0.1.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->legal-rag==0.1.0) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->legal-rag==0.1.0) (0.4.2)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.12/dist-packages (from starlette<0.51.0,>=0.40.0->fastapi>=0.110->legal-rag==0.1.0) (4.12.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi>=0.110->legal-rag==0.1.0) (3.11)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from flagembedding>=1.2.10->legal-rag==0.1.0) (2.9.0+cu126)
# Requirement already satisfied: accelerate>=0.20.1 in /usr/local/lib/python3.12/dist-packages (from flagembedding>=1.2.10->legal-rag==0.1.0) (1.12.0)
# Requirement already satisfied: peft in /usr/local/lib/python3.12/dist-packages (from flagembedding>=1.2.10->legal-rag==0.1.0) (0.18.1)
# Collecting ir-datasets (from flagembedding>=1.2.10->legal-rag==0.1.0)
#   Downloading ir_datasets-0.5.11-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from flagembedding>=1.2.10->legal-rag==0.1.0) (0.2.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from flagembedding>=1.2.10->legal-rag==0.1.0) (5.29.5)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.20.1->flagembedding>=1.2.10->legal-rag==0.1.0) (5.9.5)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.20.1->flagembedding>=1.2.10->legal-rag==0.1.0) (0.36.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.20.1->flagembedding>=1.2.10->legal-rag==0.1.0) (0.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets->colbert-ai>=0.2.19->legal-rag==0.1.0) (3.20.3)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets->colbert-ai>=0.2.19->legal-rag==0.1.0) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets->colbert-ai>=0.2.19->legal-rag==0.1.0) (0.3.8)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets->colbert-ai>=0.2.19->legal-rag==0.1.0) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets->colbert-ai>=0.2.19->legal-rag==0.1.0) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->colbert-ai>=0.2.19->legal-rag==0.1.0) (2025.3.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->colbert-ai>=0.2.19->legal-rag==0.1.0) (3.13.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->colbert-ai>=0.2.19->legal-rag==0.1.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->colbert-ai>=0.2.19->legal-rag==0.1.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->colbert-ai>=0.2.19->legal-rag==0.1.0) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->colbert-ai>=0.2.19->legal-rag==0.1.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->colbert-ai>=0.2.19->legal-rag==0.1.0) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->colbert-ai>=0.2.19->legal-rag==0.1.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->colbert-ai>=0.2.19->legal-rag==0.1.0) (1.22.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25->legal-rag==0.1.0) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25->legal-rag==0.1.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.25->legal-rag==0.1.0) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate>=0.20.1->flagembedding>=1.2.10->legal-rag==0.1.0) (1.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->legal-rag==0.1.0) (0.8.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->legal-rag==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->legal-rag==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->legal-rag==0.1.0) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->legal-rag==0.1.0) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->legal-rag==0.1.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->legal-rag==0.1.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->legal-rag==0.1.0) (2.9.0.post0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.0->legal-rag==0.1.0) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.0->legal-rag==0.1.0) (0.12.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai>=1.0->legal-rag==0.1.0) (1.3.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.8.0->legal-rag==0.1.0) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->legal-rag==0.1.0) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->legal-rag==0.1.0) (2.5.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->flagembedding>=1.2.10->legal-rag==0.1.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->flagembedding>=1.2.10->legal-rag==0.1.0) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->flagembedding>=1.2.10->legal-rag==0.1.0) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->flagembedding>=1.2.10->legal-rag==0.1.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->flagembedding>=1.2.10->legal-rag==0.1.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->flagembedding>=1.2.10->legal-rag==0.1.0) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->flagembedding>=1.2.10->legal-rag==0.1.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->flagembedding>=1.2.10->legal-rag==0.1.0) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->flagembedding>=1.2.10->legal-rag==0.1.0) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->flagembedding>=1.2.10->legal-rag==0.1.0) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->flagembedding>=1.2.10->legal-rag==0.1.0) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->flagembedding>=1.2.10->legal-rag==0.1.0) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->flagembedding>=1.2.10->legal-rag==0.1.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->flagembedding>=1.2.10->legal-rag==0.1.0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->flagembedding>=1.2.10->legal-rag==0.1.0) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->flagembedding>=1.2.10->legal-rag==0.1.0) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->flagembedding>=1.2.10->legal-rag==0.1.0) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->flagembedding>=1.2.10->legal-rag==0.1.0) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->flagembedding>=1.2.10->legal-rag==0.1.0) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.6.0->flagembedding>=1.2.10->legal-rag==0.1.0) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers->colbert-ai>=0.2.19->legal-rag==0.1.0) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->colbert-ai>=0.2.19->legal-rag==0.1.0) (0.22.2)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn>=0.27->uvicorn[standard]>=0.27->legal-rag==0.1.0) (8.3.1)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.27->legal-rag==0.1.0) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.27->legal-rag==0.1.0) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.27->legal-rag==0.1.0) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.27->legal-rag==0.1.0) (15.0.1)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from flask->colbert-ai>=0.2.19->legal-rag==0.1.0) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from flask->colbert-ai>=0.2.19->legal-rag==0.1.0) (2.2.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from flask->colbert-ai>=0.2.19->legal-rag==0.1.0) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from flask->colbert-ai>=0.2.19->legal-rag==0.1.0) (3.1.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from GitPython->colbert-ai>=0.2.19->legal-rag==0.1.0) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->GitPython->colbert-ai>=0.2.19->legal-rag==0.1.0) (5.0.2)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.12/dist-packages (from ir-datasets->flagembedding>=1.2.10->legal-rag==0.1.0) (4.13.5)
# Collecting inscriptis>=2.2.0 (from ir-datasets->flagembedding>=1.2.10->legal-rag==0.1.0)
#   Downloading inscriptis-2.7.0-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: lxml>=4.5.2 in /usr/local/lib/python3.12/dist-packages (from ir-datasets->flagembedding>=1.2.10->legal-rag==0.1.0) (6.0.2)
# Collecting trec-car-tools>=2.5.4 (from ir-datasets->flagembedding>=1.2.10->legal-rag==0.1.0)
#   Downloading trec_car_tools-2.6-py3-none-any.whl.metadata (640 bytes)
# Collecting lz4>=3.1.10 (from ir-datasets->flagembedding>=1.2.10->legal-rag==0.1.0)
#   Downloading lz4-4.4.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Collecting warc3-wet>=0.2.3 (from ir-datasets->flagembedding>=1.2.10->legal-rag==0.1.0)
#   Downloading warc3_wet-0.2.5-py3-none-any.whl.metadata (2.2 kB)
# Collecting warc3-wet-clueweb09>=0.2.5 (from ir-datasets->flagembedding>=1.2.10->legal-rag==0.1.0)
#   Downloading warc3-wet-clueweb09-0.2.5.tar.gz (17 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting zlib-state>=0.1.3 (from ir-datasets->flagembedding>=1.2.10->legal-rag==0.1.0)
#   Downloading zlib_state-0.1.10-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.5 kB)
# Collecting ijson>=3.1.3 (from ir-datasets->flagembedding>=1.2.10->legal-rag==0.1.0)
#   Downloading ijson-3.4.0.post0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (23 kB)
# Collecting unlzw3>=0.2.1 (from ir-datasets->flagembedding>=1.2.10->legal-rag==0.1.0)
#   Downloading unlzw3-0.2.3-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.4.1->ir-datasets->flagembedding>=1.2.10->legal-rag==0.1.0) (2.8.3)
# Collecting lxml>=4.5.2 (from ir-datasets->flagembedding>=1.2.10->legal-rag==0.1.0)
#   Downloading lxml-5.4.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.5 kB)
# Collecting cbor>=1.0.0 (from trec-car-tools>=2.5.4->ir-datasets->flagembedding>=1.2.10->legal-rag==0.1.0)
#   Downloading cbor-1.0.0.tar.gz (20 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->legal-rag==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->legal-rag==0.1.0) (2025.3)
# Collecting pdfminer.six==20251230 (from pdfplumber->legal-rag==0.1.0)
#   Downloading pdfminer_six-20251230-py3-none-any.whl.metadata (4.3 kB)
# Collecting pypdfium2>=4.18.0 (from pdfplumber->legal-rag==0.1.0)
#   Downloading pypdfium2-5.3.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (67 kB)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six==20251230->pdfplumber->legal-rag==0.1.0) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber->legal-rag==0.1.0) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber->legal-rag==0.1.0) (3.0)
# Requirement already satisfied: ipython>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from pyvis->legal-rag==0.1.0) (7.34.0)
# Requirement already satisfied: jsonpickle>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from pyvis->legal-rag==0.1.0) (4.1.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis->legal-rag==0.1.0) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis->legal-rag==0.1.0) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis->legal-rag==0.1.0) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis->legal-rag==0.1.0) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis->legal-rag==0.1.0) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis->legal-rag==0.1.0) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis->legal-rag==0.1.0) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=5.3.0->pyvis->legal-rag==0.1.0) (4.9.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->pyvis->legal-rag==0.1.0) (0.5.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=5.3.0->pyvis->legal-rag==0.1.0) (0.7.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from sentence-transformers->legal-rag==0.1.0) (1.6.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers->legal-rag==0.1.0) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers->legal-rag==0.1.0) (3.6.0)
# Downloading colbert_ai-0.2.22-py3-none-any.whl (116 kB)
# Downloading faiss_cpu-1.13.2-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (23.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 58.1 MB/s  0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 70.6 MB/s  0:00:00
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
# Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Downloading bitarray-3.8.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (340 kB)
# Downloading ir_datasets-0.5.11-py3-none-any.whl (866 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 866.1/866.1 kB 48.9 MB/s  0:00:00
# Downloading ijson-3.4.0.post0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (149 kB)
# Downloading inscriptis-2.7.0-py3-none-any.whl (45 kB)
# Downloading lxml-5.4.0-cp312-cp312-manylinux_2_28_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 102.1 MB/s  0:00:00
# Downloading lz4-4.4.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 72.5 MB/s  0:00:00
# Downloading trec_car_tools-2.6-py3-none-any.whl (8.4 kB)
# Downloading unlzw3-0.2.3-py3-none-any.whl (6.7 kB)
# Downloading warc3_wet-0.2.5-py3-none-any.whl (18 kB)
# Downloading zlib_state-0.1.10-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (22 kB)
# Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (180 kB)
# Downloading pdfplumber-0.11.9-py3-none-any.whl (60 kB)
# Downloading pdfminer_six-20251230-py3-none-any.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 95.3 MB/s  0:00:00
# Downloading pypdfium2-5.3.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 109.6 MB/s  0:00:00
# Downloading pyvis-0.3.2-py3-none-any.whl (756 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 35.7 MB/s  0:00:00
# Downloading ujson-5.11.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (57 kB)
# Building wheels for collected packages: legal-rag, flagembedding, cbor, warc3-wet-clueweb09
#   Building editable for legal-rag (pyproject.toml): started
#   Building editable for legal-rag (pyproject.toml): finished with status 'done'
#   Created wheel for legal-rag: filename=legal_rag-0.1.0-py3-none-any.whl size=7269 sha256=b70a0d71e8a4cfcb7d4769d64bb7b70e9bade5cdd46415423dfbd25943dc96ca
#   Stored in directory: /tmp/pip-ephem-wheel-cache-wkw4n3cj/wheels/b1/4e/d0/f1b06fac085448eac52a545584c2a992ac2c72ac2704cc1cf4
#   Building wheel for flagembedding (pyproject.toml): started
#   Building wheel for flagembedding (pyproject.toml): finished with status 'done'
#   Created wheel for flagembedding: filename=flagembedding-1.3.5-py3-none-any.whl size=233819 sha256=3234ed2c7a2a3ca14b6bb0dcbc672fedf5b006d3e2f966269dfd7092f6ddc83f
#   Stored in directory: /root/.cache/pip/wheels/b2/1f/f6/78f862bb80cb959cc9960b7c4e2d1f702b1bc0e79d19b5f124
#   Building wheel for cbor (pyproject.toml): started
#   Building wheel for cbor (pyproject.toml): finished with status 'done'
#   Created wheel for cbor: filename=cbor-1.0.0-cp312-cp312-linux_x86_64.whl size=55067 sha256=aebb9016317b45477483d82b063ef2829c8317defb614ae9864155d1212c1f48
#   Stored in directory: /root/.cache/pip/wheels/44/3e/21/a739cbcc331a1ab45c326d6edbdac6118de4402f6076e30ff1
#   Building wheel for warc3-wet-clueweb09 (pyproject.toml): started
#   Building wheel for warc3-wet-clueweb09 (pyproject.toml): finished with status 'done'
#   Created wheel for warc3-wet-clueweb09: filename=warc3_wet_clueweb09-0.2.5-py3-none-any.whl size=18996 sha256=e4a2d04ef96e7f4489e36c47cb0c9ce7618d3b3d28cb1dd8387da722cfebf108
#   Stored in directory: /root/.cache/pip/wheels/f6/85/c2/9f0f621def52a1d5db7d29984f81e45f9fb6dfeb1a4eb6e31c
# Successfully built legal-rag flagembedding cbor warc3-wet-clueweb09
# Installing collected packages: warc3-wet-clueweb09, warc3-wet, cbor, bitarray, zlib-state, unlzw3, ujson, trec-car-tools, rank-bm25, pypdfium2, ninja, lz4, lxml, loguru, jedi, ijson, faiss-cpu, inscriptis, pyvis, pdfminer.six, ir-datasets, pdfplumber, colbert-ai, flagembedding, legal-rag
#   Attempting uninstall: lxml
#     Found existing installation: lxml 6.0.2
#     Uninstalling lxml-6.0.2:
#       Successfully uninstalled lxml-6.0.2
#
# Successfully installed bitarray-3.8.0 cbor-1.0.0 colbert-ai-0.2.22 faiss-cpu-1.13.2 flagembedding-1.3.5 ijson-3.4.0.post0 inscriptis-2.7.0 ir-datasets-0.5.11 jedi-0.19.2 legal-rag-0.1.0 loguru-0.7.3 lxml-5.4.0 lz4-4.4.5 ninja-1.13.0 pdfminer.six-20251230 pdfplumber-0.11.9 pypdfium2-5.3.0 pyvis-0.3.2 rank-bm25-0.2.2 trec-car-tools-2.6 ujson-5.11.0 unlzw3-0.2.3 warc3-wet-0.2.5 warc3-wet-clueweb09-0.2.5 zlib-state-0.1.10
# Dependencies installed.

# %% [markdown]
# ## Data preprocess
#
# Before the LegalRAG pipeline can serve queries, the legal corpus must be transformed into structured, searchable representations.
#
# In the offline preprocessing stage, raw legal texts are converted into normalized data artifacts, retrieval indices, and a legal knowledge graph through the following steps:
#
# 1. **Preprocess law files**
#
#    Raw legal documents are parsed, cleaned, and normalized into a unified JSONL format. Each legal provision is assigned a stable identifier and enriched with structural metadata such as law name, part, chapter, article number, and source file.
#
#    ```bash
#    python -m scripts.preprocess_law
#    ```
#
# 2. **Build retrieval indices**
#
#    Multiple complementary retrieval indices are constructed to support lexical, dense, and late-interaction search paradigms:
#
#    * **BM25** for sparse keyword-based retrieval
#    * **FAISS** for dense vector similarity search
#    * **ColBERT** for token-level late interaction retrieval
#
#    ```bash
#    python -m scripts.build_index
#    ```
#
# 3. **Construct the legal knowledge graph**
#
#    Legal articles are connected via structured relationships (e.g., citation, reference, dependency), forming a directed legal knowledge graph that enables graph-based expansion and contextual reasoning.
#
#    ```bash
#    python -m scripts.build_graph
#    ```

# %%
#| include: false

# For demo purpose, load preprocessed law data
# !python -m data.download_data
# Out:
# [download_data] data dir=/content/Legal-RAG/data
# [download_data] repo_id=flora-l/lawdata repo_type=dataset zip=data.zip
# [download_data] downloaded_zip=/root/.cache/huggingface/hub/datasets--flora-l--lawdata/blobs/63e60bac842926eefdfda633ec808baef802d442208d99d8a66ff7a84c8a3ad5
# [download_data] wrote: /content/Legal-RAG/data/download_ucc.py
# [download_data] wrote: /content/Legal-RAG/data/download_data.py
# [download_data] wrote: /content/Legal-RAG/data/graph/law_graph.html
# [download_data] wrote: /content/Legal-RAG/data/graph/law_graph_en.jsonl
# [download_data] wrote: /content/Legal-RAG/data/graph/law_graph_zh.jsonl
# [download_data] wrote: /content/Legal-RAG/data/raw/minfadian.txt
# [download_data] wrote: /content/Legal-RAG/data/raw/ucc/ucc_2.txt
# [download_data] wrote: /content/Legal-RAG/data/raw/ucc/ucc_2A.txt
# [download_data] wrote: /content/Legal-RAG/data/raw/ucc/ucc_9.txt
# [download_data] wrote: /content/Legal-RAG/data/raw/ucc/ucc_3.txt
# [download_data] wrote: /content/Legal-RAG/data/raw/ucc/ucc_6.txt
# [download_data] wrote: /content/Legal-RAG/data/raw/ucc/ucc_4A.txt
# [download_data] wrote: /content/Legal-RAG/data/raw/ucc/ucc_5.txt
# [download_data] wrote: /content/Legal-RAG/data/raw/ucc/ucc_4.txt
# [download_data] wrote: /content/Legal-RAG/data/raw/ucc/ucc_1.txt
# [download_data] wrote: /content/Legal-RAG/data/raw/ucc/ucc_7.txt
# [download_data] wrote: /content/Legal-RAG/data/raw/ucc/ucc_8.txt
# [download_data] wrote: /content/Legal-RAG/data/processed/law_zh.jsonl
# [download_data] wrote: /content/Legal-RAG/data/processed/law_en.jsonl
# [download_data] wrote: /content/Legal-RAG/data/index/en/bm25.pkl
# [download_data] wrote: /content/Legal-RAG/data/index/en/colbert/.colbert_build.lock
# [download_data] wrote: /content/Legal-RAG/data/index/en/colbert/colbert_meta.jsonl
# [download_data] wrote: /content/Legal-RAG/data/index/en/colbert/experiment/indexes/law/plan.json
# [download_data] wrote: /content/Legal-RAG/data/index/en/colbert/experiment/indexes/law/0.metadata.json
# [download_data] wrote: /content/Legal-RAG/data/index/en/colbert/experiment/indexes/law/buckets.pt
# [download_data] wrote: /content/Legal-RAG/data/index/en/colbert/experiment/indexes/law/0.residuals.pt
# [download_data] wrote: /content/Legal-RAG/data/index/en/colbert/experiment/indexes/law/metadata.json
# [download_data] wrote: /content/Legal-RAG/data/index/en/colbert/experiment/indexes/law/doclens.0.json
# [download_data] wrote: /content/Legal-RAG/data/index/en/colbert/experiment/indexes/law/0.codes.pt
# [download_data] wrote: /content/Legal-RAG/data/index/en/colbert/experiment/indexes/law/ivf.pid.pt
# [download_data] wrote: /content/Legal-RAG/data/index/en/colbert/experiment/indexes/law/centroids.pt
# [download_data] wrote: /content/Legal-RAG/data/index/en/colbert/experiment/indexes/law/avg_residual.pt
# [download_data] wrote: /content/Legal-RAG/data/index/en/faiss/faiss.index
# [download_data] wrote: /content/Legal-RAG/data/index/en/faiss/faiss_meta.jsonl
# [download_data] wrote: /content/Legal-RAG/data/index/zh/bm25.pkl
# [download_data] wrote: /content/Legal-RAG/data/index/zh/colbert/.colbert_build.lock
# [download_data] wrote: /content/Legal-RAG/data/index/zh/colbert/colbert_meta.jsonl
# [download_data] wrote: /content/Legal-RAG/data/index/zh/colbert/experiment/indexes/law/plan.json
# [download_data] wrote: /content/Legal-RAG/data/index/zh/colbert/experiment/indexes/law/0.metadata.json
# [download_data] wrote: /content/Legal-RAG/data/index/zh/colbert/experiment/indexes/law/buckets.pt
# [download_data] wrote: /content/Legal-RAG/data/index/zh/colbert/experiment/indexes/law/0.residuals.pt
# [download_data] wrote: /content/Legal-RAG/data/index/zh/colbert/experiment/indexes/law/metadata.json
# [download_data] wrote: /content/Legal-RAG/data/index/zh/colbert/experiment/indexes/law/doclens.0.json
# [download_data] wrote: /content/Legal-RAG/data/index/zh/colbert/experiment/indexes/law/0.codes.pt
# [download_data] wrote: /content/Legal-RAG/data/index/zh/colbert/experiment/indexes/law/ivf.pid.pt
# [download_data] wrote: /content/Legal-RAG/data/index/zh/colbert/experiment/indexes/law/centroids.pt
# [download_data] wrote: /content/Legal-RAG/data/index/zh/colbert/experiment/indexes/law/avg_residual.pt
# [download_data] wrote: /content/Legal-RAG/data/index/zh/faiss/faiss.index
# [download_data] wrote: /content/Legal-RAG/data/index/zh/faiss/faiss_meta.jsonl
# [download_data] done. All files merged into data/.

# %% [markdown]
# **Generated Data Artifacts:**

# %%
#| echo: false
#| code-fold: false

from pathlib import Path
import pandas as pd
from legalrag.config import AppConfig

cfg = AppConfig.load(None)
cfg_zh = cfg.with_lang("zh")
cfg_en = cfg.with_lang("en")
base_dir = Path(cfg.paths.data_dir).parent

def _rel(p: Path) -> str:
    try:
        return str(p.resolve().relative_to(base_dir))
    except Exception:
        return str(p)

targets = [
    ("zh", "Processed", Path(cfg_zh.paths.law_jsonl)),
    ("en", "Processed", Path(cfg_en.paths.law_jsonl)),
    ("zh", "Index", Path(cfg_zh.retrieval.bm25_index_file)),
    ("en", "Index", Path(cfg_en.retrieval.bm25_index_file)),
    ("zh", "Index", Path(cfg_zh.retrieval.faiss_index_file)),
    ("en", "Index", Path(cfg_en.retrieval.faiss_index_file)),
    ("zh", "Index", Path(cfg_zh.retrieval.faiss_meta_file)),
    ("en", "Index", Path(cfg_en.retrieval.faiss_meta_file)),
    ("zh", "Index", Path(cfg_zh.retrieval.colbert_meta_file)),
    ("en", "Index", Path(cfg_en.retrieval.colbert_meta_file)),
    ("zh", "Graph", Path(cfg_zh.paths.law_graph_jsonl)),
    ("en", "Graph", Path(cfg_en.paths.law_graph_jsonl)),
]

rows = []
for lang, category, p in targets:
    rows.append({
        "Lang": lang,
        "Category": category,
        "Path": _rel(p),
        "Exists": p.exists(),
        "Size (MB)": round(p.stat().st_size / (1024**2), 3) if p.exists() else None,
    })

df = pd.DataFrame(rows).sort_values(["Lang", "Category", "Path"])
df
# Out:
#    Lang   Category                                      Path  Exists  \
# 11   en      Graph             data/graph/law_graph_en.jsonl    True
# 3    en      Index                    data/index/en/bm25.pkl    True
# 9    en      Index  data/index/en/colbert/colbert_meta.jsonl    True
# 5    en      Index           data/index/en/faiss/faiss.index    True
# 7    en      Index      data/index/en/faiss/faiss_meta.jsonl    True
# 1    en  Processed               data/processed/law_en.jsonl    True
# 10   zh      Graph             data/graph/law_graph_zh.jsonl    True
# 2    zh      Index                    data/index/zh/bm25.pkl    True
# 8    zh      Index  data/index/zh/colbert/colbert_meta.jsonl    True
# 4    zh      Index           data/index/zh/faiss/faiss.index    True
# 6    zh      Index      data/index/zh/faiss/faiss_meta.jsonl    True
# 0    zh  Processed               data/processed/law_zh.jsonl    True
#
#     Size (MB)
# 11      0.228
# 3       1.796
# 9       0.987
# 5       1.884
# 7       0.962
# 1       0.982
# 10      0.405
# 2       0.992
# 8       0.654
# 4       4.018
# 6       0.601
# 0       0.658

# %% [markdown]
# Example entries from `law_zh.jsonl` and `law_en.jsonl`:

# %%
#| echo: false
#| code-fold: false

import json
import pandas as pd
from legalrag.config import AppConfig
from IPython.display import display

cfg = AppConfig.load(None)
paths = {
    "zh": Path(cfg.with_lang("zh").paths.law_jsonl),
    "en": Path(cfg.with_lang("en").paths.law_jsonl),
}

for lang, jsonl_path in paths.items():
    samples = []
    if not jsonl_path.exists():
        continue
    with jsonl_path.open("r", encoding="utf-8") as f:
        for i, line in enumerate(f):
            if i >= 3:
                break
            obj = json.loads(line)
            obj["lang"] = lang
            samples.append(obj)

    display(pd.json_normalize(samples).drop(columns=["subpart", "part", "chapter", "section", "article_key"], errors="ignore"))
# Out:
#                  id    law_name lang article_no article_id  \
# 0  minfadian.txt::一  中华人民共和国民法典   zh        第一条          1
# 1  minfadian.txt::二  中华人民共和国民法典   zh        第二条          2
# 2  minfadian.txt::三  中华人民共和国民法典   zh        第三条          3
#
#                                                 text         source
# 0  第一条 为了保护民事主体的合法权益，调整民事关系，维护社会和经济秩序，适应中国特色社会主义发...  minfadian.txt
# 1             第二条 民法调整平等主体的自然人、法人和非法人组织之间的人身关系和财产关系。  minfadian.txt
# 2      第三条 民事主体的人身权利、财产权利以及其他合法权益受法律保护，任何组织或者个人不得侵犯。  minfadian.txt
#                  id                 law_name lang article_no article_id  \
# 0  ucc_1.txt::1-101  Uniform Commercial Code   en    § 1-101      1-101
# 1  ucc_1.txt::1-102  Uniform Commercial Code   en    § 1-102      1-102
# 2  ucc_1.txt::1-103  Uniform Commercial Code   en    § 1-103      1-103
#
#                                                 text     source
# 0  § 1-101. Short Titles.(a) This [Act] may be ci...  ucc_1.txt
# 1  § 1-102. Scope of Article.This article applies...  ucc_1.txt
# 2  § 1-103. Construction of Uniform Commercial Co...  ucc_1.txt

# %% [markdown]
# | Field        | Description                     |
# | ------------ | ------------------------------- |
# | `id`         | Internal numeric identifier     |
# | `law_name`   | Name of the law                 |
# | `lang`       | Language of the law article     |
# | `article_no` | Article number (human-readable) |
# | `article_id` | Stable article identifier       |
# | `text`       | Full article text               |
# | `source`     | Original source file            |

# %%
#| include: false

meta_path = Path(cfg.retrieval.faiss_meta_file)
assert meta_path.exists(), f"Not found: {meta_path}"

meta_n = sum(1 for _ in meta_path.open("r", encoding="utf-8"))

print(f"faiss_meta.jsonl records: {meta_n}")
# Out:
# faiss_meta.jsonl records: 1260

# %% [markdown]
# ## Initialize the RAG pipeline

# %% [markdown]
# This section sets up the RAG pipeline and configures the underlying language model. The pipeline is constructed from a centralized configuration, ensuring that retrieval, ranking, and generation components are consistently parameterized.

# %%
#| include: false

from pathlib import Path
from IPython.display import display, Markdown, clear_output
import asyncio
from typing import Any, Optional, List
from legalrag.utils.logger import get_logger
import time
import json as _json

logger = get_logger(__name__)

# %%
#| code-fold: false
#| output: false

from legalrag.pipeline.rag_pipeline import RagPipeline
from legalrag.config import AppConfig

cfg = AppConfig.load(None)
cfg.llm.provider = "qwen-local"
cfg.llm.model = "Qwen/Qwen2.5-3B-Instruct"
pipeline = RagPipeline(cfg)
# Out:
# [Feb 02, 03:29:22] #> Loading codec...
# [Feb 02, 03:29:22] Loading decompress_residuals_cpp extension (set COLBERT_LOAD_TORCH_EXTENSION_VERBOSE=True for more info)...
# [Feb 02, 03:30:42] Loading packbits_cpp extension (set COLBERT_LOAD_TORCH_EXTENSION_VERBOSE=True for more info)...
# [Feb 02, 03:32:03] #> Loading IVF...
# [Feb 02, 03:32:03] #> Loading doclens...
# [Feb 02, 03:32:03] #> Loading codes and residuals...

# %% [markdown]
# The default configuration uses local Qwen model as the generation model by default, and it can be switched to an OpenAI model:
#
# ```python
# cfg.llm.provider = "openai"
# cfg.llm.model = "gpt-4.1-mini"
# # Requires setting OPENAI_API_KEY in environment variables
# ```

# %%
#| include: false

import torch
from scripts.quiet import install_quiet

torch.cuda.empty_cache()
install_quiet()

# %% [markdown]
# ## Query Understanding and Routing

# %% [markdown]
# This step distinguishes between different query types and selects a retrieval mode accordingly.
#
# Accurate query understanding is critical, as it directly influences downstream retrieval strategies and answer generation behavior.

# %%
#| code-summary: "Route the query (Query type and mode) : "
#| code-fold: false

from legalrag.routing.router import QueryRouter
from legalrag.llm.client import LLMClient

llm = LLMClient.from_config(cfg)
router = QueryRouter(llm_client=llm, llm_based=cfg.routing.llm_based)
question = '已经有两个亲生孩子的家庭可以再收养一个孩子吗?'
decision = router.route(question)
print('Issue Type: ', decision.issue_type)
print('Task Type: ', decision.task_type)
print('mode: ', decision.mode)
# Out:
# Issue Type:  IssueType.MARRIAGE_FAMILY
# Task Type:  TaskType.JUDGE_STYLE
# mode:  RoutingMode.RAG

# %% [markdown]
# ## Retrieve legal provisions

# %% [markdown]
# In this stage, the system retrieves candidate legal provisions relevant to the query.
#
# LegalRAG uses a multi-channel retrieval strategy that combines dense semantic search, sparse lexical matching, and late-interaction models. Depending on the retrieval mode inferred during query understanding, a graph-based enhancement stage may be applied to expand the candidate set with structurally related legal provisions. Final ranking is refined using cross-encoder or LLM-based reranking.

# %%
#| include: false

from legalrag.schemas import RetrievalHit
from typing import Any, Optional, List
import pandas as pd
pd.set_option('display.max_colwidth', None)

def hits_to_dataframe(hits: List[RetrievalHit]) -> pd.DataFrame:
    rows = []
    for h in hits:
        c = h.chunk
        sb = getattr(h, "score_breakdown", None) or {}
        rows.append(
            {
                "score": f"{float(getattr(h, 'score', 0.0) or 0.0):.2f}",
                "channel": sb.get("channel", ""),
                "article_id": getattr(c, "article_id", ""),
                # "chapter": getattr(c, "chapter", ""),
                "preview": (getattr(c, "text", "") or "").replace("\n", " ")[:150] + "...",
            }
        )
    return pd.DataFrame(rows)

# %%
#| code-fold: false

question = '已经有两个亲生孩子的家庭可以再收养一个孩子吗?'
_, hits, _ = pipeline.retrieve(question, llm, top_k=10, decision=decision)
hits_to_dataframe(hits)
# Out:
#   score                 channel article_id                                                                                                                                                    preview
# 0  1.04  [dense, colbert, bm25]       1100                                                   第一千一百条 无子女的收养人可以收养两名子女；有子女的收养人只能收养一名子女。 收养孤儿、残疾未成年人或者儿童福利机构抚养的查找不到生父母的未成年人，可以不受前款和本法第一千零九十八条第一项规定的限制。...
# 1  0.67        [dense, colbert]       1103                                                                                                   第一千一百零三条 继父或者继母经继子女的生父母同意，可以收养继子女，并可以不受本法第一千零九十三条第三项、...
# 2  0.55        [dense, colbert]       1099                                                                                                             第一千零九十九条 收养三代以内旁系同辈血亲的子女，可以不受本法第一千零九十三条第三项、...
# 3  0.40           [dense, bm25]       1101                                                                                                                             第一千一百零一条 有配偶者收养子女，应当夫妻共同收养。...
# 4  0.31         [bm25, colbert]        699                                                                  第六百九十九条 同一债务有两个以上保证人的，保证人应当按照保证合同约定的保证份额，承担保证责任；没有约定保证份额的，债权人可以请求任何一个保证人在其保证范围内承担保证责任。...
# 5  0.31        [dense, colbert]       1117                                            第一千一百一十七条 收养关系解除后，养子女与养父母以及其他近亲属间的权利义务关系即行消除，与生父母以及其他近亲属间的权利义务关系自行恢复。但是，成年养子女与生父母以及其他近亲属间的权利义务关系是否恢复，可以协商确定。...
# 6  0.26        [colbert, dense]       1098                                 第一千零九十八条 收养人应当同时具备下列条件： （一）无子女或者只有一名子女； （二）有抚养、教育和保护被收养人的能力； （三）未患有在医学上认为不应当收养子女的疾病； （四）无不利于被收养人健康成长的违法犯罪记录； （五）年满三十周岁。...
# 7  0.23        [dense, colbert]       1097                                                                                                        第一千零九十七条 生父母送养子女，应当双方共同送养。生父母一方不明或者查找不到的，可以单方送养。...
# 8  0.23         [bm25, colbert]       1105  第一千一百零五条 收养应当向县级以上人民政府民政部门登记。收养关系自登记之日起成立。 收养查找不到生父母的未成年人的，办理登记的民政部门应当在登记前予以公告。 收养关系当事人愿意签订收养协议的，可以签订收养协议。 收养关系当事人各方或者一方要求办理收养公证的，应当办理收养公证。 县级以上人民政府民政...
# 9  0.18         [bm25, colbert]       1114  第一千一百一十四条 收养人在被收养人成年以前，不得解除收养关系，但是收养人、送养人双方协议解除的除外。养子女八周岁以上的，应当征得本人同意。 收养人不履行抚养义务，有虐待、遗弃等侵害未成年养子女合法权益行为的，送养人有权要求解除养父母与养子女间的收养关系。送养人、收养人不能达成解除收养关系协议的，可...

# %%
#| code-fold: false

question = 'What standards must goods satisfy to be merchantable？'
_, hits, _ = pipeline.retrieve(question, llm, top_k=10, decision=decision)
hits_to_dataframe(hits)
# Out:
#   score                 channel article_id                                                                                                                                                    preview
# 0  1.07  [dense, bm25, colbert]     2A-212  § 2A-212. IMPLIED WARRANTY OF MERCHANTABILITY. (1) Except in a finance lease, a warranty that the goods will be merchantable is implied in a lease contrac...
# 1  1.01  [dense, colbert, bm25]      2-314  § 2-314. Implied Warranty: Merchantability; Usage of Trade. (1) Unless excluded or modified (Section2-316), a warranty that the goods shall be merchanta...
# 2  0.34        [dense, colbert]     2A-511  § 2A-511. MERCHANT LESSEE's DUTIES AS TO RIGHTFULLY REJECTED GOODS. (1) Subject to any security interest of a lessee (Section2A-508(5)), if a lessor or as...
# 3  0.34         [bm25, colbert]      2-105  § 2-105. Definitions: Transferability; "Goods"; "Future" Goods; "Lot"; "Commercial Unit". (1)"Goods" means all things (including specially manufacture...
# 4  0.33        [dense, colbert]      2-603  § 2-603. Merchant Buyer's Duties as to Rightfully Rejected Goods. (1) Subject to any security interest in the buyer (subsection (3) of Section2-711), wh...
# 5  0.18        [colbert, dense]      7-207  § 7-207. Goods Must Be Kept Separate; Fungible Goods.(a) Unless the warehouse receipt provides otherwise, a warehouse shall keep separate the goods covere...

# %% [markdown]
# The result shows how different retrieval signals contributed to the final ranking for debugging, evaluation, and trust in legal AI systems.

# %% [markdown]
# ## Answer legal questions

# %% [markdown]
# Using the retrieved provisions as evidence, the system generates a final answer.
#
# Answer generation is explicitly grounded in the retrieved legal texts, ensuring that conclusions are traceable to authoritative sources.

# %%
#| include: false

from IPython.display import display, Markdown

def render_legal_json_md(data):
    INDENT = "  "

    def indent(text, level=1):
        return INDENT * level + text
    lines = []
    for section in data.get("sections", []):
        title = section.get("title", "")
        items = section.get("items", [])

        lines.append(f"**{title}**")

        if title in ("参考法条", "Referenced Provisions"):
            for item in items:
                if isinstance(item, dict):
                    law = item.get("law_name", "")
                    no = item.get("article_no", "")
                    header = " · ".join([x for x in [law, no] if x])
                    lines.append(f"- {header}")
                else:
                    lines.append(f"- {item}")
        else:
            num_items = len(items)
            for i, item in enumerate(items, 1):
                if isinstance(item, str):
                    if num_items == 1:
                      lines.append(f">  {item}")
                    else:
                      lines.append(f"{i}. {item}")
                elif isinstance(item, dict):
                    quotation = item.get("quotation")
                    explanation = item.get("explanation", "")
                    if quotation:
                        if isinstance(quotation, dict):
                            q_law = quotation.get("law_name", "")
                            q_no = quotation.get("article_no", "")
                            q_text = quotation.get("content", "")
                            for line in q_text.splitlines():
                                lines.append(f"> *{line}*")
                        else:
                          if num_items == 1:
                            lines.append(f"> *「{quotation}」*")
                          else:
                            lines.append(f"{i}. *「{quotation}」*")
                    if explanation:
                        lines.append(f"\n> {explanation}\n")
                else:
                    if num_items == 1:
                      lines.append(f"  {item}")
                    else:
                      lines.append(f"{i}. {item}")

        lines.append("")  # blank line between sections

    display(Markdown("\n\n".join(lines)))

# %%
#| code-summary: "Question 1: 已经有两个孩子的家庭可以再收养一个孩子吗?"

question = '已经有两个孩子的家庭可以再收养一个孩子吗?'
answer = pipeline.answer(question).answer
render_legal_json_md(json.loads(answer))
# Out:
# **结论**
#
# >  已有两个孩子的家庭不可以再收养一个孩子。
#
#
#
# **分析论证**
#
# > *第一千一百条 无子女的收养人可以收养两名子女；有子女的收养人只能收养一名子女。*
#
#
# > 根据《中华人民共和国民法典》第一百一百条规定，已婚人士即使有两个孩子也不能再收养另一个孩子。
#
#
#
#
# **参考法条**
#
# - 民法典 · 第「1100」条

# %%
#| code-summary: "Question 2: What standards must goods satisfy to be merchantable？"

question = 'What standards must goods satisfy to be merchantable？'
answer = pipeline.answer(question).answer
render_legal_json_md(json.loads(answer))
# Out:
# **Conclusion**
#
# >  The goods must meet the criteria outlined in the Uniform Commercial Code to be considered merchantable.
#
#
#
# **Reasoning**
#
# > *Except in a finance lease, a warranty that the goods will be merchantable is implied in a lease contract if the lessor is a merchant with respect to goods of that kind.*
#
#
# > For goods to be merchantable according to the Uniform Commercial Code, the lessor must be deemed a merchant concerning the type of goods involved.
#
#
# > *(a) Pass without objection in the trade under the description in the lease agreement;*
#
#
# > Goods are considered merchantable if they pass inspection without objections during trading under the agreed-upon description.
#
#
# > *(b) In the case of fungible goods, are of fair average quality within the description;*
#
#
# > Fungible goods are deemed merchantable if they maintain fair average quality relative to the described standard.
#
#
# > *(c) Are fit for the ordinary purposes for which goods of that type are used;*
#
#
# > Merchantable goods must fulfill the typical uses intended for goods of their type.
#
#
# > *(d) Run, within the variation permitted by the lease agreement, of even kind, quality, and quantity within each unit and among all units involved;*
#
#
# > Each unit and all units of the goods must adhere to the specified variance limits set forth in the lease agreement.
#
#
# > *(e) Are adequately contained, packaged, and labeled as the lease agreement may require;*
#
#
# > The goods must be properly stored, packed, and labeled in accordance with the lease agreement.
#
#
# > *(f) Conform to any promises or affirmations of fact made on the container or label;*
#
#
# > The goods must comply with any explicit representations about the product on its packaging or labels.
#
#
#
#
# **Referenced Provisions**
#
# - Uniform Commercial Code · 2A-212
